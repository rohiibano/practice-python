# %%
x = 5    #int
y =  5.6 #float
z = 8j   #complex

#convert from int to float
a = float(x)

#convert from float to int
b = int(y)

#convert from int to complex
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 5.0
# 5
# (5+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
x = int(1)
y = int(2.8)
z = int("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x = float(1)
y = float(2.8)
z = float("3")
w = float("4.2")
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.2
