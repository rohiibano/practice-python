# %%
x = 5
y = 8

#sum operator
print(x+y)
# Out:
# 13

# %%
x = 5
y = 8


print(x-y)
# Out:
# -3

# %%
x = 5
y = 8


print(x/y)
# Out:
# 0.625

# %%
x = 5
y = 8


print(x*y)
# Out:
# 40

# %%
x = 5
y = 8


print(x%y)
# Out:
# 5

# %%
x = 5
y = 8


print(x//y)
# Out:
# 0

# %%
x = 5
x+= 8


print(x)
# Out:
# 13

# %%
x= 8
x-= 5


print(x)
# Out:
# 3

# %%
x = 5
x*= 8


print(x)
# Out:
# 40

# %%
x = 5
x/= 8


print(x)
# Out:
# 0.625

# %%
x = 5
x%= 8


print(x)
# Out:
# 5

# %%
x = 5
x**= 8


print(x)
# Out:
# 390625

# %%
x = 5
x//= 8


print(x)
# Out:
# 0

# %%
x = 5
x|= 8


print(x)
# Out:
# 13

# %%
x = 5
x>>= 8


print(x)
# Out:
# 0

# %%
x = 5
x<<= 8


print(x)
# Out:
# 1280

# %%
print(x := 3)
# Out:
# 3
