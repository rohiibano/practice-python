# %%
print("Welcome")
var1 = 25
var2 = 3
mod = var1 % var2
print("the mode of", var1, "on" , var2,"is:",mod)
# Out:
# Welcome
# the mode of 25 on 3 is: 1

# %%
ages = (30, 35, 56, 65)
print(list(ages))
print(type(ages))

students = range(3,10,4)
print(list(students))
print(type(students))

ages = [30, 35, 56, 65]
print((ages))
print(type(ages))

ages = True
print((ages))
print(type(ages))
# Out:
# [30, 35, 56, 65]
# <class 'tuple'>
# [3, 7]
# <class 'range'>
# [30, 35, 56, 65]
# <class 'list'>
# True
# <class 'bool'>

# %%
x = 2       #int
y = 2.5     #float
z= 3 +2j    #complex
print(x)
print(type(x))
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# 2
# <class 'int'>
# 2.5
# <class 'float'>
# (3+2j)
# <class 'complex'>

# %%
x = 5    #int
y =  5.6 #float
z = 8j   #complex

#convert from int to float
a = float(x)

#convert from float to int
b = int(y)

#convert from int to complex
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 5.0
# 5
# (5+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
import random
print(random.randrange(1,10))
# Out:
# 5
