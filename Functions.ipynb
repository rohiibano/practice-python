# %%
#A function is a block of code which only runs when it is called.

#You can pass data, known as parameters, into a function.

#A function can return data as a result.
#functions
#userdefined functions
#without parameter , no input , no return
#function definition
#function call
#function header
def sum():
  a = 6
  b = 8
  c = a+b
  print("The sum of a and b is:",c)

# %%
#function call
sum()
# Out:
# The sum of a and b is: 14

# %%
def sum1(a,b):
  c = a+b
  print("The sum of a and b is :",c)

# %%
sum1(35,65)
# Out:
# The sum of a and b is : 100

# %%
def even_odd(n):
  if n%2 ==0:
    print("the number is even")
  else:
    print("the number is odd")

# %%
even_odd(65)
# Out:
# the number is odd

# %%
def odd_even(n):
  if n%2==0:
    print(n,"is even")
  else:
    print(n,"is odd")

# %%
for b in range(1,51):
  odd_even(b)
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even
# 11 is odd
# 12 is even
# 13 is odd
# 14 is even
# 15 is odd
# 16 is even
# 17 is odd
# 18 is even
# 19 is odd
# 20 is even
# 21 is odd
# 22 is even
# 23 is odd
# 24 is even
# 25 is odd
# 26 is even
# 27 is odd
# 28 is even
# 29 is odd
# 30 is even
# 31 is odd
# 32 is even
# 33 is odd
# 34 is even
# 35 is odd
# 36 is even
# 37 is odd
# 38 is even
# 39 is odd
# 40 is even
# 41 is odd
# 42 is even
# 43 is odd
# 44 is even
# 45 is odd
# 46 is even
# 47 is odd
# 48 is even
# 49 is odd
# 50 is even

# %%
def type(n):   #even_odd another method
  if n%2==0:
    return "even"
  else:
    return "odd"

# %%
ans=type(36)
print(ans)
# Out:
# even

# %%
def my_function():
  print("Hello from a fnction")


my_function()
# Out:
# Hello from a fnction

# %%
#arguments
def my_function(fname):
  print(fname + " Maryam")

my_function("Mahnoor")
my_function("kiran")
my_function("Kinza")
# Out:
# Mahnoor Maryam
# kiran Maryam
# Kinza Maryam

# %%
def kname(lname,mname):
  print(lname + " "+mname)

kname("Maryam", "Nadia")
# Out:
# Maryam Nadia

# %%
def pm(*females):
  print("The Youngest Girl is " + females[3])

pm("kiran","Mahnoor","Ayesha","Nadia",78)
# Out:
# The Youngest Girl is Nadia

# %%
def m_functin(n1, n2, n3):
  print("The Youngest child is:" +" ", n2)

m_functin(n1="kinza", n2="nadia" , n3="maryam")
# Out:
# The Youngest child is:  nadia

# %%
def u_function(**males):
  print("This is your answer:"+ males["Iname"])

u_function(fname = "kiran", Iname = "nadia")
# Out:
# This is your answer:nadia

# %%
#default parameter value
#If we call the function without argument, it uses the default value:
def n_function(country = "Swedan"):
  print("I am from:" + country)

#n_function("USA")
#n_function("Malaisia")
n_function()
#n_function("Pakistan")
# Out:
# I am from:Swedan

# %%
def k_function(food):
  for x in food:
    print(x)

fruits = ["apple", "banana", "cherry", "kivi"]

k_function(fruits)
# Out:
# apple
# banana
# cherry
# kivi

# %%
  def m_function(k):
    return k*6

print(m_function(2))
# Out:
# 12

# %%
#pass function when ther is non value is assigned to any function then pass this function to avoid any error

def pass_function():
  pass

# %%
def s_function(x, /):
  print(x)

s_function(2)
# Out:
# 2

# %%
def my_function(x):
  print(x)

my_function(x = 3)
my_function(3)
# Out:
# 3
# 3

# %%
#keyword only arguments
def s_function(*,x):
  print(x)

s_function(x=3)

#Without the *, you are allowed to use positionale arguments even if the function expects keyword arguments:
# Out:
# 3

# %%
#Combine Positional-Only and Keyword-Only

def k(x,y,/,*, n,z):
  print(x,y,n,z)

k(5,9,n=6,z=8)
# Out:
# 5 9 6 8

# %%
#recursion function is call itself function
def tri_recursion(R):
  if R>0:
    result = R + tri_recursion(R-1)
    print(result)
  else:
    result = 0
    return result

  print("/n/n Print Result")
  tri_recursion(6)
