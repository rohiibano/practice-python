# %%
x = 23
y = 2.65
z = 2j

print(x)
print(type(x))
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# 23
# <class 'int'>
# 2.65
# <class 'float'>
# 2j
# <class 'complex'>

# %%
x = 35e3
y = 12E4
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
