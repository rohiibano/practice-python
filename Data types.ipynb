# %%
x = "Hello World"
print(x)
print(type(x))
# Out:
# Hello World
# <class 'str'>

# %%
x = "Hello World"

#display x:
print(x)

#display the data type of x:
print(type(x))
# Out:
# Hello World
# <class 'str'>

# %%
x = 20.5

#display x:
print(x)

#display the data type of x:
print(type(x))
# Out:
# 20.5
# <class 'float'>

# %%
x = 1j

#display x:
print(x)

#display the data type of x:
print(type(x))
# Out:
# 1j
# <class 'complex'>

# %%
x = ["banana", "Apple", "Mango"]
print(x)
print(type(x))
# Out:
# ['banana', 'Apple', 'Mango']
# <class 'list'>

# %%
x = ("banana", "Apple", "Mango")
print(x)
print(type(x))
# Out:
# ('banana', 'Apple', 'Mango')
# <class 'tuple'>

# %%
ages= range(4,15,3)
print(list(ages))
print(type(ages))
# Out:
# [4, 7, 10, 13]
# <class 'range'>

# %%
x = {"name" : "Jahn" , "Ayesha": "Nimra"}
print(x)
print(type(x))
# Out:
# {'name': 'Jahn', 'Ayesha': 'Nimra'}
# <class 'dict'>

# %%
x = {"name" , "Jahn" , "Ayesha", "Nimra"}
print(x)
print(type(x))
# Out:
# {'Nimra', 'name', 'Ayesha', 'Jahn'}
# <class 'set'>

# %%
x = True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>
